# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.46M/6.46M [00:00<00:00, 25.8MB/s]

# %%
url = "https://globalvoices.org/page/2/"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Close the dialogue box
browser.links.find_by_partial_text("No thanks").click()

# %%
# List to contain article info
articles_list = []

# %%
def get_summary():
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    
    main_area = soup.find("div", class_="post-archive-container")
    articles = main_area.find_all("div", class_="gv-promo-card-text")
    
    for article in articles:
        header = article.find("h3", class_="post-title").text.strip()
        date = article.find("span", class_="datestamp")["title"]
        date = date.replace('_', '')
        
        
        summary_dict = {
            "header1": header,
            "date1": date
        }
        articles_list.append(summary_dict)

# %%
for _ in range(5):
    get_summary()
    browser.links.find_by_partial_text("Older").click()

# %%
articles_list
# Out:
# [{'header1': 'Student-run press in Thailand offered money by Chinese investor to stop operating',
#   'date1': '30 10 2022'},
#  {'header1': 'Dolma Diaries attempts to break down stereotypes and enmity, one episode at a time',
#   'date1': '28 10 2022'},
#  {'header1': 'Azerbaijan’s thriving feminist movement: challenges and perspectives',
#   'date1': '28 10 2022'},
#  {'header1': 'Indonesia rallies to support women in Iran amid concerns over rising domestic conservatism',
#   'date1': '28 10 2022'},
#  {'header1': "Three violent acts per day during Brazil's first round of elections, according to survey",
#   'date1': '28 10 2022'},
#  {'header1': 'YouTuber Wang Jixian continues to tell the story of Odesa to sinophone audiences',
#   'date1': '27 10 2022'},
#  {'header1': 'Undertones: Brazil copes with ‘digital militias’ ahead of tense elections',
#   'date1': '27 10 2022'},
#  {'header1': 'Leonie ‘Miss Lee’ Forbes, beloved doyenne of Jamaican stage and film, passes away at 85',
#   'date1': '26 10 2022'},
#  {'header1': 'Giant cats on walls: Odesa street art inspired by the war, but not only',
#   'date1': '26 10 2022'},
#  {'header1': 'Armenia is rocked by the suicide of a gay couple',
#   'date1': '26 10 2022'},
#  {'header1': 'Explaining the 20th Congress of the Communist Party of China: Struggle and fight',
#   'date1': '26 10 2022'},
#  {'header1': '‘A girl with a Hindu heart’', 'date1': '25 10 2022'},
#  {'header1': 'Police detains scores of activists at an opposition party rally in Azerbaijan',
#   'date1': '25 10 2022'},
#  {'header1': 'Klinika Bernardo pioneers, innovates community health care for HIV patients in the Philippines',
#   'date1': '25 10 2022'},
#  {'header1': 'One of the last Ladino language speakers in Bosnia, Moris Albahari, passed away',
#   'date1': '25 10 2022'},
#  {'header1': 'In Trinidad & Tobago, Divali remains a festival beloved by people of all faiths',
#   'date1': '24 10 2022'},
#  {'header1': 'How Palestinian youth resisted Israeli occupation: With a haircut',
#   'date1': '24 10 2022'},
#  {'header1': 'Activists predict homophobic and transphobic violence in Russia, but most avenues of escape are slammed shut',
#   'date1': '24 10 2022'},
#  {'header1': "‘Call them by their names': Stories of Russian anti-war political prisoners",
#   'date1': '24 10 2022'},
#  {'header1': 'How the hot chilli pepper ‘Akabare’ came to tickle the taste-buds of Nepali noodle lovers',
#   'date1': '24 10 2022'},
#  {'header1': 'More guns, fewer control mechanisms: Brazilian journalist analyzes Bolsonaro’s gun policy',
#   'date1': '23 10 2022'},
#  {'header1': 'Brazilian candidates reduce attention on peripheral neighborhoods in 2022 elections',
#   'date1': '22 10 2022'},
#  {'header1': 'Explaining the 20th Congress of the Communist Party of China: Jiangshan',
#   'date1': '21 10 2022'},
#  {'header1': "Australia's unique natural wonders are at risk from ecotourism expansion",
#   'date1': '21 10 2022'},
#  {'header1': "The love and hate relationship of Hungary's ruling party Fidesz and Facebook",
#   'date1': '21 10 2022'},
#  {'header1': 'Turkish lawmakers ratify new disinformation bill',
#   'date1': '21 10 2022'},
#  {'header1': 'Ola Bini, the cyberactivist who causes panic in Ecuador',
#   'date1': '21 10 2022'},
#  {'header1': 'Filming Gyani Maiya Sen who inspired efforts to revive the dying Kusunda language in Nepal',
#   'date1': '20 10 2022'},
#  {'header1': 'In Ukraine, the war has reshaped language to create new idioms',
#   'date1': '20 10 2022'},
#  {'header1': "From ‘forerunner’ to ‘a puppy': How Mongolia got hooked on Russia's ‘Pivot to Asia’",
#   'date1': '20 10 2022'},
#  {'header1': 'Citizen journalists face challenges in Cambodia, Thailand, and Myanmar',
#   'date1': '19 10 2022'},
#  {'header1': 'Ugandan poet spreads her message despite new law to criminalize online dissent',
#   'date1': '19 10 2022'},
#  {'header1': "‘The fight for human rights begins in the kitchen': Interview with Czech writer Radka Denemarková",
#   'date1': '19 10 2022'},
#  {'header1': 'Can Jamaica efficiently make the much-needed transition to renewable energy?',
#   'date1': '18 10 2022'},
#  {'header1': 'The struggle to maintain an independent russophone voice in Moldova',
#   'date1': '18 10 2022'},
#  {'header1': 'Kianoush Ramezani: The journey of an exiled political cartoonist',
#   'date1': '17 10 2022'},
#  {'header1': 'Russian social media users now also want to say no to war while not actually saying it',
#   'date1': '17 10 2022'},
#  {'header1': "Murder of two queer people by far-right teen signals worsening plight of Slovakia's LGBTQ+ community",
#   'date1': '17 10 2022'},
#  {'header1': 'The sudden passing of Haitian singer ‘Mikaben’ leaves a big void in the music world',
#   'date1': '17 10 2022'},
#  {'header1': "Will banning music glorifying violence from the airwaves reduce Jamaica's crime rate?",
#   'date1': '16 10 2022'},
#  {'header1': 'Nong Bua Lamphu massacre in Thailand: Recounting mistakes, seeking a way forward',
#   'date1': '16 10 2022'},
#  {'header1': "Albania's tourism industry is on the rise, increasing risk of child sexual exploitation, warns new report",
#   'date1': '16 10 2022'},
#  {'header1': 'China censors online chatter after anti-Xi Jinping protest; Hong Kong media muted',
#   'date1': '15 10 2022'},
#  {'header1': 'In the face of stubborn adherence to outdated dress codes, one Trinidadian citizen gets creative',
#   'date1': '14 10 2022'},
#  {'header1': 'The true colours of Truecaller in India: app accused of being negligent about data privacy',
#   'date1': '14 10 2022'},
#  {'header1': 'Ukrainians and Russians turn to Twitter memes about Elon Musk, but this time the tone is no longer humorous',
#   'date1': '14 10 2022'},
#  {'header1': 'Activists decry shrinking freedom of expression in the Philippines',
#   'date1': '14 10 2022'},
#  {'header1': 'Digitization of public services in Albania has increased their quality, digital rights analyst claims',
#   'date1': '14 10 2022'},
#  {'header1': 'Photographer Aleksandr Yakimchuk recreates Odesa in black-and-white',
#   'date1': '14 10 2022'},
#  {'header1': 'Can music and feminism help heal border conflicts in Central Asia?',
#   'date1': '14 10 2022'},
#  {'header1': 'The world must hear the voice of Iranian women',
#   'date1': '13 10 2022'},
#  {'header1': 'The Civic Media Observatory: Making sense of people’s speech, memes, and tweets',
#   'date1': '13 10 2022'},
#  {'header1': 'Water scarcity in Indigenous communities should be reported on, a young Bolivian journalist says',
#   'date1': '13 10 2022'},
#  {'header1': "“We also speak Russian in Moldova, but don't want to have anything to do with the so-called Russian World”, says Moldovan writer Iulian Ciocan",
#   'date1': '13 10 2022'},
#  {'header1': "Activists speculate on Elon Musk's foreign influence after proposing Ukraine and Taiwan peace deals",
#   'date1': '13 10 2022'},
#  {'header1': 'The death of 69 Gambian children from Indian-made cough syrups sparks public outrage',
#   'date1': '11 10 2022'},
#  {'header1': 'Can citizens of democracies still trust the law? A Global Voices Insights discussion',
#   'date1': '11 10 2022'},
#  {'header1': 'Iranian protest crackdown targets ethnic minorities',
#   'date1': '10 10 2022'},
#  {'header1': "Armenia and Azerbaijan recognize each other's territorial integrity",
#   'date1': '10 10 2022'},
#  {'header1': "‘When the porridge is hot, one eats it on the side': Haiti's current protests, explained on Twitter",
#   'date1': '9 10 2022'},
#  {'header1': "‘Explainer,’ Trinidad & Tobago's ‘calypso messenger,’ passes on",
#   'date1': '8 10 2022'},
#  {'header1': "Why most Salvadorans want Bukele's re-election despite his growing authoritarianism",
#   'date1': '7 10 2022'},
#  {'header1': "Of coal pots, bicycles and macaroni pie: Is Trinidad & Tobago's government out of touch?",
#   'date1': '7 10 2022'},
#  {'header1': 'Indian farmers are pushed to despair with huge bank loans',
#   'date1': '7 10 2022'},
#  {'header1': 'Russians fleeing Putin’s war face long border queues, overpriced flights, fear, and uncertainty',
#   'date1': '7 10 2022'},
#  {'header1': 'Is the ‘water machine of Bengal’ preventing more flood disasters in Bangladesh?',
#   'date1': '7 10 2022'},
#  {'header1': 'Civil society groups call for justice after a radio broadcaster is killed in the Philippines',
#   'date1': '7 10 2022'},
#  {'header1': "Twiplomacy:\xa0Uganda's General Muhoozi's tweets threaten peace in East African Region",
#   'date1': '7 10 2022'},
#  {'header1': 'Blood and democracy: the fight for animal rights in Azerbaijan',
#   'date1': '7 10 2022'},
#  {'header1': 'Twitter Space: The Ukrainian language and its global significance',
#   'date1': '6 10 2022'},
#  {'header1': 'Schools close as lingering weather system continues to affect Trinidad & Tobago',
#   'date1': '6 10 2022'},
#  {'header1': 'Trinidad & Tobago suffers the effects of yet another tropical weather system',
#   'date1': '6 10 2022'},
#  {'header1': 'Unfreedom Monitor report: Data Governance',
#   'date1': '6 10 2022'},
#  {'header1': 'Hong Kong’s wealth gap reaches ‘tipping point’ under COVID as unemployment rises among poor',
#   'date1': '6 10 2022'},
#  {'header1': 'Why are so many teachers giving up their careers in Hong Kong?',
#   'date1': '6 10 2022'},
#  {'header1': 'Brazil’s first round of elections: left scores historical wins but bolsonarism still strong',
#   'date1': '5 10 2022'},
#  {'header1': 'Women in Turkey stand in solidarity with women of Iran',
#   'date1': '4 10 2022'},
#  {'header1': 'Supporters hold rallies around the world in solidarity with the Iranian people',
#   'date1': '4 10 2022'},
#  {'header1': 'A young chef in Baku turns his flat into a restaurant',
#   'date1': '4 10 2022'},
#  {'header1': 'Cubans initiate new wave of protests over blackouts and hunger',
#   'date1': '4 10 2022'},
#  {'header1': "In Brazil's election year, women in politics denounce recurring threats",
#   'date1': '3 10 2022'},
#  {'header1': 'Portugal apologizes for colonial massacre in Mozambique',
#   'date1': '3 10 2022'},
#  {'header1': 'Angola’s elections: the incumbent MPLA wins, but the opposition disputes results',
#   'date1': '3 10 2022'},
#  {'header1': "Catholics and evangelicals may get to decide Brazil's next president",
#   'date1': '2 10 2022'},
#  {'header1': 'Under Bolsonaro, political attacks gain institutional legitimacy in Brazil',
#   'date1': '2 10 2022'},
#  {'header1': 'The great escape from Russia: Live on Russian Twitter',
#   'date1': '30 09 2022'},
#  {'header1': 'Filipino writers and academics push back against book censorship',
#   'date1': '30 09 2022'},
#  {'header1': 'Papua New Guinea’s new media rules could undermine the work of journalists',
#   'date1': '30 09 2022'},
#  {'header1': "Why fear of a coup attempt is on the horizon in Brazil's elections",
#   'date1': '29 09 2022'},
#  {'header1': 'Brazil’s courts debate use of billboards in political campaigns',
#   'date1': '29 09 2022'},
#  {'header1': 'Unfreedom Monitor report: Morocco', 'date1': '29 09 2022'},
#  {'header1': 'Undertones: Anti-army hashtags gain rare visibility in Pakistan',
#   'date1': '29 09 2022'},
#  {'header1': "‘The Art of the Steal?': Russia’s online voting problem",
#   'date1': '29 09 2022'},
#  {'header1': 'A Georgian neo-Nazi group finds a home on YouTube',
#   'date1': '29 09 2022'},
#  {'header1': "Nepal's Citizenship Bill attracts renewed controversy",
#   'date1': '29 09 2022'},
#  {'header1': "Iran's most recent protests are unprecedented — here is why",
#   'date1': '28 09 2022'},
#  {'header1': 'Croatia’s push for controversial electoral reform undermines democratic development of Bosnia and Herzegovina',
#   'date1': '27 09 2022'},
#  {'header1': 'Turkish citizens feel the squeeze of increased EU visa rejections',
#   'date1': '27 09 2022'},
#  {'header1': '‘Where’s the President?’ trends as super typhoon batters the Philippines',
#   'date1': '27 09 2022'},
#  {'header1': 'The Nicaraguan government looks to imprison Catholic priests and stain their image',
#   'date1': '26 09 2022'},
#  {'header1': 'Hong Kong attempts to reconnect with the world by relaxing COVID-19 travel restrictions',
#   'date1': '26 09 2022'},
#  {'header1': 'My journey to learning Ukrainian and the online language tools that took me there',
#   'date1': '26 09 2022'},
#  {'header1': 'The Greek spyware scandal: When technology outpaces governance',
#   'date1': '26 09 2022'},
#  {'header1': 'Far from home, alone: Cambodian students share life in Thailand during the pandemic lockdown',
#   'date1': '25 09 2022'},
#  {'header1': 'Hong Kong press freedom index sinks to new low as media outlets disappear',
#   'date1': '25 09 2022'}]

# %%
import pandas as pd
df = pd.DataFrame(articles_list)
df.head()
# Out:
#                                              header1       date1
# 0  Student-run press in Thailand offered money by...  30 10 2022
# 1  Dolma Diaries attempts to break down stereotyp...  28 10 2022
# 2  Azerbaijan’s thriving feminist movement: chall...  28 10 2022
# 3  Indonesia rallies to support women in Iran ami...  28 10 2022
# 4  Three violent acts per day during Brazil's fir...  28 10 2022

# %%
df.date = pd.to_datetime(df.date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33184\3331931521.py in <module>
# ----> 1 df.date = pd.to_datetime(df.date)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'date'

# %%
df

# %%
df.info()

# %%
browser.quit()
